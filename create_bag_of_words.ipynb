# %%
import pandas as pd
from collections import Counter, defaultdict
import nltk
from nltk.tokenize import word_tokenize, RegexpTokenizer
nltk.download('punkt')
nltk.download('stopwords')

tokenizer = RegexpTokenizer(r'\w+')
# Out:
# [nltk_data] Downloading package punkt to /home/u4/zawad1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/u4/zawad1/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def lower_case_elements(arr) -> list:
    return [x.lower() for x in arr]

# %%
df = pd.read_csv("final_training_data.csv")
pd.set_option('display.max_colwidth', None)
stopwords = nltk.corpus.stopwords.words('spanish')
sample_texts = df['article']
sample_texts = [sample_text.translate(str.maketrans('', '', string.punctuation)) for sample_text in sample_texts]

# %%
sample_texts, stopwords = lower_case_elements(sample_texts), set(lower_case_elements(stopwords))

# %%
word_counts = defaultdict(lambda: 0)
for text in sample_texts:
    tokens = set(word_tokenize(text)) - stopwords
    token_counts = Counter(tokens)
    for token in token_counts:
        word_counts[token] += token_counts[token]

print(word_counts)
# Out:
# defaultdict(<function <lambda> at 0x7f795feada60>, {'escisión': 34, 'caída': 720, 'convertido': 1516, 'portaba': 26, 'misma': 1320, 'salir': 536, 'poquísimo': 6, 'extinguir': 6, 'inesperadamente': 16, 'encabezado': 108, 'rico': 204, 'repitió': 48, 'activo': 360, 'prisión': 1956, 'recibiera': 34, 'observó': 208, 'económicamente': 96, 'carnal': 8, 'templarios': 432, 'evitar': 1094, 'formaron': 136, 'perfiles': 3092, 'acusación': 540, 'agosto': 1544, 'beneficiada': 10, 'agregar': 44, 'ambiguo': 28, 'diciembre': 1466, 'mejor': 1300, 'sureños': 108, 'beneficio': 268, 'afirma': 860, '1993': 170, 'latino': 38, 'traficantes': 1628, 'ciudades': 1060, 'selección': 152, 'libre': 752, 'disposición': 294, 'detalle': 156, 'libertad': 1030, 'prefieren': 144, 'hacen': 1234, 'desembolsarían': 4, 'manera': 2650, 'fin': 2342, 'toda': 1716, 'protegía': 38, 'perdió': 234, 'amenaza': 1166, 'nacional': 4628, 'hicieron': 756, '“': 9090, 'pacto': 294, 'notables': 72, 'oriundos': 10, 'caucásicas': 4, 'carlos': 1174, 'data': 244, 'capturados': 628, 'sangre': 430, 'pago': 550, 'montes': 52, 'llama': 572, 'ven': 480, 'cerró': 146, 'órdenes': 700, 'planteó': 58, 'emisario': 36, 'colega': 62, 'ocho': 1220, 'pronunciarse': 22, 'décadas': 844, 'clan': 376, 'potencial': 420, 'reunión': 526, 'ángeles': 216, '2012': 2882, 'presentó': 752, 'dicho': 1240, 'vendió': 108, 'tirar': 44, 'primera': 2182, 'administración': 1892, 'guzmán': 682, 'mientras': 4132, 'erradicarían': 4, 'pertenecía': 136, 'ambicioso': 90, 'participando': 122, 'joaquín': 624, 'mayo': 1856, 'máxima': 484, 'especial': 1484, 'hecho': 3888, 'golpear': 80, 'trascender': 16, 'quedó': 392, 'clica': 152, 'trataba': 196, '35': 372, 'enfurecido': 18, 'quedaron': 282, 'entregó': 358, 'vea': 8432, 'propuso': 172, 'sumergiéndose': 4, 'remover': 34, 'ésta': 370, 'aterrizadas': 4, 'logró': 612, 'americanos': 254, 'largo': 2326, 'pólvora': 24, 'supo': 160, 'inmediatamente': 268, 'carteles': 1586, 'america': 108, 'mara': 690, 'seguridad': 6262, 'chingaría': 4, 'criminal': 4490, 'sospechas': 384, 'viaje': 414, 'suministradas': 24, 'robles': 14, 'bajo': 3338, 'ánimos': 40, 'sonia': 38, 'anzuelo': 8, 'oriundo': 42, 'escasa': 104, 'mutuos': 22, 'cambios': 826, 'propio': 660, 'mexicano': 1466, 'adam': 74, 'comunicó': 36, 'cifrado': 10, 'ganancias': 1538, '48': 254, 'jugada': 44, 'prisiones': 806, 'atrás': 442, 'clarita': 8, 'filas': 466, 'garcía': 578, 'michoacán': 534, 'agrupación': 84, 'picounion': 4, 'mismo': 3018, 'diversos': 546, 'medio': 2560, 'mercancía': 208, 'negociación': 354, 'fence': 8, 'corría': 32, 'kilos': 790, 'fronteras': 714, 'alguno': 220, 'sumarse': 32, 'michoacanos': 20, 'pese': 1276, 'conocida': 1162, 'tareas': 214, '13': 1018, 'logística': 276, 'liquidado': 12, 'fast': 12, 'comenzaría': 16, 'importaba': 58, 'predecible': 26, 'enero': 2046, 'aceptó': 162, 'distribuidores': 166, 'quería': 224, 'quizá': 718, 'interior': 1394, 'asumidas': 14, 'compuesta': 140, 'incrustarse': 4, 'desarrollan': 52, 'códigos': 72, 'modo': 434, 'investigando': 368, 'cuál': 216, 'casi': 2924, 'seno': 36, 'comunicaron': 20, 'pública': 1960, 'cuenta': 2020, 'salvadoreña': 328, 'señores': 78, 'ocasión': 198, 'andaba': 26, 'confiar': 64, 'resultados': 1042, 'americana': 36, 'organización': 3578, 'puesto': 1044, 'alcanzó': 194, 'actividades': 3104, 'entorno': 182, 'decidieron': 180, 'marzo': 1724, 'llevó': 988, 'embarrado': 4, 'tres': 3592, 'man': 14, 'concretar': 28, 'policiales': 1072, 'dejó': 902, 'impenetrables': 6, 'apaciguó': 4, 'calentó': 4, 'convirtió': 714, 'recluido': 116, 'conocidos': 838, 'cien': 138, 'repetidas': 150, 'giradas': 4, 'instruyera': 4, 'morder': 10, 'casual': 28, 'si': 5374, 'monetariamente': 4, 'judicial': 1330, 'primeros': 1182, 'aún': 2992, 'concretarlo': 4, 'luis': 1092, 'dígito': 14, 'verdaderamente': 56, 'menudistas': 4, 'metanfetmina': 4, 'forma': 1848, 'sacarle': 22, 'acusado': 1446, 'zozobra': 16, 'cinco': 2218, 'día': 2064, 'tráfico': 4626, 'consta': 142, 'mensajeras': 8, 'inequívoca': 10 ...

# %%
with open("word_counts_in_crime_data.txt", 'a+') as f:
    for elem in sorted(word_counts.items(), key=lambda item: item[1], reverse=True):
        f.write(str(elem))
